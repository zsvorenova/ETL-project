# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt

# %%
#read csv into pandas
file1 = "Resources/healthcare_census.csv"
healthcare_census = pd.read_csv(file1)
healthcare_census.head(10)
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# 5  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        60001
# 6  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        70001
# 7  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        90001
# 8  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        80001
# 9  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC       100002
#
#                                 Provider Name     Provider Street Address  \
# 0            SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1                    ALASKA REGIONAL HOSPITAL            2801 DEBARR ROAD
# 2        BANNER GOOD SAMARITAN MEDICAL CENTER     1111 EAST MCDOWELL ROAD
# 3  WASHINGTON REGIONAL MED CTR AT NORTH HILLS     3215 N NORTH HILLS BLVD
# 4                          ST JOSEPH HOSPITAL             2700 DOLBEER ST
# 5               NORTH COLORADO MEDICAL CENTER            1801 16TH STREET
# 6                      HOSPITAL OF ST RAPHAEL              1450 CHAPEL ST
# 7             GEORGE WASHINGTON UNIV HOSPITAL              900 23RD ST NW
# 8       CHRISTIANA CARE HEALTH SERVICES, INC.  4755 OGLETOWN-STANTON ROAD
# 9                  BETHESDA MEMORIAL HOSPITAL        2815 S SEACREST BLVD
#
#    Provider City Provider State  Provider Zip Code  \
# 0         DOTHAN             AL              36301
# 1      ANCHORAGE             AK              99508
# 2        PHOENIX             AZ              85006
# 3   FAYETTEVILLE             AR              72703
# 4         EUREKA             CA              95501
# 5        GREELEY             CO              80631
# 6      NEW HAVEN             CT               6511
# 7     WASHINGTON             DC              20037
# 8         NEWARK             DE              19718
# 9  BOYNTON BEACH             FL              33435
#
#   Hospital Referral Region Description Total Discharges  \
# 0                          AL - Dothan               91
# 1                       AK - Anchorage               23
# 2                         AZ - Phoenix               11
# 3                      AR - Springdale               39
# 4                         CA - Redding               48
# 5                         CO - Greeley               16
# 6                       CT - New Haven               50
# 7                      DC - Washington               11
# 8                      DE - Wilmington               90
# 9                 FL - Fort Lauderdale               23
#
#   Average Covered Charges Average Total Payments Average Medicare Payments  \
# 0               32,963.07               5,777.24                  4,763.73
# 1               34,805.13               8,401.95                  6,413.78
# 2               34,803.81               7,768.90                  6,951.45
# 3               30,470.56               5,811.56                  4,372.61
# 4               44,664.45               8,227.14                  6,936.52
# 5               33,135.68               8,359.12                  5,379.06
# 6               18,103.18               8,099.68                  7,112.92
# 7               57,137.45              10,582.81                  8,871.00
# 8               14,336.66               7,494.76                  6,071.21
# 9               40,686.73               6,523.78                  5,339.82
#
#    Summary Level State  State FIPS Insured Males 18-25 Noninsured Males 18-25  \
# 0             40    AL           1             173,849                 58,849
# 1             40    AK           2              26,917                 12,275
# 2             40    AZ           4             233,098                 92,136
# 3             40    AR           5             101,489                 40,199
# 4             40    CA           6           1,458,114                515,578
# 5             40    CO           8             199,090                 55,076
# 6             40    CT           9             145,369                 25,759
# 7             40    DC          11              31,771                  3,712
# 8             40    DE          10              37,479                  6,340
# 9             40    FL          12             580,489                289,512
#
#   Females 18-25 with Insurance Females 18-25 without insurance
# 0                      188,498                          48,144
# 1                       25,692                           8,152
# 2                      245,929                          72,752
# 3                      105,642                          34,898
# 4                    1,511,793                         403,457
# 5                      203,107                          41,910
# 6                      149,262                          17,433
# 7                       42,265                           2,042
# 8                       40,390                           4,704
# 9                      624,879                         235,730

# %%
#fill (or change) any NaNs to 0
healthcare_census.fillna(0)
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# 3       WASHINGTON REGIONAL MED CTR AT NORTH HILLS
# 4                               ST JOSEPH HOSPITAL
# ...                                            ...
# 163060               BAKERSFIELD MEMORIAL HOSPITAL
# 163061                          GROSSMONT HOSPITAL
# 163062                      MERCY GENERAL HOSPITAL
# 163063                          ST HELENA HOSPITAL
# 163064                    PENINSULA MEDICAL CENTER
#
#                    Provider Street Address Provider City Provider State  \
# 0                   1108 ROSS CLARK CIRCLE        DOTHAN             AL
# 1                         2801 DEBARR ROAD     ANCHORAGE             AK
# 2                  1111 EAST MCDOWELL ROAD       PHOENIX             AZ
# 3                  3215 N NORTH HILLS BLVD  FAYETTEVILLE             AR
# 4                          2700 DOLBEER ST        EUREKA             CA
# ...                                    ...           ...            ...
# 163060                420 34TH ST BOX 1888   BAKERSFIELD             CA
# 163061  5555 GROSSMONT CENTER DRIVE BOX 58       LA MESA             CA
# 163062                           4001 J ST    SACRAMENTO             CA
# 163063                    10 WOODLAND ROAD  SAINT HELENA             CA
# 163064                1501 TROUSDALE DRIVE    BURLINGAME             CA
#
#         Provider Zip Code Hospital Referral Region Description  \
# 0                   36301                          AL - Dothan
# 1                   99508                       AK - Anchorage
# 2                   85006                         AZ - Phoenix
# 3                   72703                      AR - Springdale
# 4                   95501                         CA - Redding
# ...                   ...                                  ...
# 163060              93301                     CA - Bakersfield
# 163061              91942                       CA - San Diego
# 163062              95819                      CA - Sacramento
# 163063              94574                            CA - Napa
# 163064              94010                CA - San Mateo County
#
#        Total Discharges Average Covered Charges Average Total Payments  \
# 0                    91               32,963.07               5,777.24
# 1                    23               34,805.13               8,401.95
# 2                    11               34,803.81               7,768.90
# 3                    39               30,470.56               5,811.56
# 4                    48               44,664.45               8,227.14
# ...                 ...                     ...                    ...
# 163060               21               53,334.80               8,012.23
# 163061               26               40,062.46               7,449.80
# 163062               27               66,207.66              10,863.22
# 163063               17              105,929.47               9,438.00
# 163064               16               51,950.87               7,863.00
#
#        Average Medicare Payments  Summary Level State  State FIPS  \
# 0                       4,763.73             40    AL           1
# 1                       6,413.78             40    AK           2
# 2                       6,951.45             40    AZ           4
# 3                       4,372.61             40    AR           5
# 4                       6,936.52             40    CA           6
# ...                          ...            ...   ...         ...
# 163060                  6,213.19             40    CA           6
# 163061                  6,358.07             40    CA           6
# 163062                  6,924.70             40    CA           6
# 163063                  8,376.35             40    CA           6
# 163064                  6,872.50             40    CA           6
#
#        Insured Males 18-25 Noninsured Males 18-25  \
# 0                  173,849                 58,849
# 1                   26,917                 12,275
# 2                  233,098                 92,136
# 3                  101,489                 40,199
# 4                1,458,114                515,578
# ...                    ...                    ...
# 163060           1,458,114                515,578
# 163061           1,458,114                515,578
# 163062           1,458,114                515,578
# 163063           1,458,114                515,578
# 163064           1,458,114                515,578
#
#        Females 18-25 with Insurance Females 18-25 without insurance
# 0                           188,498                          48,144
# 1                            25,692                           8,152
# 2                           245,929                          72,752
# 3                           105,642                          34,898
# 4                         1,511,793                         403,457
# ...                             ...                             ...
# 163060                    1,511,793                         403,457
# 163061                    1,511,793                         403,457
# 163062                    1,511,793                         403,457
# 163063                    1,511,793                         403,457
# 163064                    1,511,793                         403,457
#
# [163065 rows x 19 columns]

# %%
#drop any rows with no values
healthcare_census1 = healthcare_census.dropna(how="any")
healthcare_census1
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        20017
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        30002
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        40004
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                                      Provider Name  \
# 0                 SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         ALASKA REGIONAL HOSPITAL
# 2             BANNER GOOD SAMARITAN MEDICAL CENTER
# 3       WASHINGTON REGIONAL MED CTR AT NORTH HILLS
# 4                               ST JOSEPH HOSPITAL
# ...                                            ...
# 163060               BAKERSFIELD MEMORIAL HOSPITAL
# 163061                          GROSSMONT HOSPITAL
# 163062                      MERCY GENERAL HOSPITAL
# 163063                          ST HELENA HOSPITAL
# 163064                    PENINSULA MEDICAL CENTER
#
#                    Provider Street Address Provider City Provider State  \
# 0                   1108 ROSS CLARK CIRCLE        DOTHAN             AL
# 1                         2801 DEBARR ROAD     ANCHORAGE             AK
# 2                  1111 EAST MCDOWELL ROAD       PHOENIX             AZ
# 3                  3215 N NORTH HILLS BLVD  FAYETTEVILLE             AR
# 4                          2700 DOLBEER ST        EUREKA             CA
# ...                                    ...           ...            ...
# 163060                420 34TH ST BOX 1888   BAKERSFIELD             CA
# 163061  5555 GROSSMONT CENTER DRIVE BOX 58       LA MESA             CA
# 163062                           4001 J ST    SACRAMENTO             CA
# 163063                    10 WOODLAND ROAD  SAINT HELENA             CA
# 163064                1501 TROUSDALE DRIVE    BURLINGAME             CA
#
#         Provider Zip Code Hospital Referral Region Description  \
# 0                   36301                          AL - Dothan
# 1                   99508                       AK - Anchorage
# 2                   85006                         AZ - Phoenix
# 3                   72703                      AR - Springdale
# 4                   95501                         CA - Redding
# ...                   ...                                  ...
# 163060              93301                     CA - Bakersfield
# 163061              91942                       CA - San Diego
# 163062              95819                      CA - Sacramento
# 163063              94574                            CA - Napa
# 163064              94010                CA - San Mateo County
#
#        Total Discharges Average Covered Charges Average Total Payments  \
# 0                    91               32,963.07               5,777.24
# 1                    23               34,805.13               8,401.95
# 2                    11               34,803.81               7,768.90
# 3                    39               30,470.56               5,811.56
# 4                    48               44,664.45               8,227.14
# ...                 ...                     ...                    ...
# 163060               21               53,334.80               8,012.23
# 163061               26               40,062.46               7,449.80
# 163062               27               66,207.66              10,863.22
# 163063               17              105,929.47               9,438.00
# 163064               16               51,950.87               7,863.00
#
#        Average Medicare Payments  Summary Level State  State FIPS  \
# 0                       4,763.73             40    AL           1
# 1                       6,413.78             40    AK           2
# 2                       6,951.45             40    AZ           4
# 3                       4,372.61             40    AR           5
# 4                       6,936.52             40    CA           6
# ...                          ...            ...   ...         ...
# 163060                  6,213.19             40    CA           6
# 163061                  6,358.07             40    CA           6
# 163062                  6,924.70             40    CA           6
# 163063                  8,376.35             40    CA           6
# 163064                  6,872.50             40    CA           6
#
#        Insured Males 18-25 Noninsured Males 18-25  \
# 0                  173,849                 58,849
# 1                   26,917                 12,275
# 2                  233,098                 92,136
# 3                  101,489                 40,199
# 4                1,458,114                515,578
# ...                    ...                    ...
# 163060           1,458,114                515,578
# 163061           1,458,114                515,578
# 163062           1,458,114                515,578
# 163063           1,458,114                515,578
# 163064           1,458,114                515,578
#
#        Females 18-25 with Insurance Females 18-25 without insurance
# 0                           188,498                          48,144
# 1                            25,692                           8,152
# 2                           245,929                          72,752
# 3                           105,642                          34,898
# 4                         1,511,793                         403,457
# ...                             ...                             ...
# 163060                    1,511,793                         403,457
# 163061                    1,511,793                         403,457
# 163062                    1,511,793                         403,457
# 163063                    1,511,793                         403,457
# 163064                    1,511,793                         403,457
#
# [163065 rows x 19 columns]

# %%
healthcare_census1 = healthcare_census1.loc[healthcare_census1["State"] == "CA", :]
healthcare_census1
# Out:
#                                   DRG Definition  Provider Id  \
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50006
# 55                948 - SIGNS & SYMPTOMS W/O MCC        50763
# 106               948 - SIGNS & SYMPTOMS W/O MCC        50761
# 157               948 - SIGNS & SYMPTOMS W/O MCC        50757
# 208               948 - SIGNS & SYMPTOMS W/O MCC        50755
# ...                                          ...          ...
# 163060  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50036
# 163061  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50026
# 163062  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50017
# 163063  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50013
# 163064  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        50007
#
#                             Provider Name             Provider Street Address  \
# 4                      ST JOSEPH HOSPITAL                     2700 DOLBEER ST
# 55             SILVER LAKE MEDICAL CENTER             1711 WEST TEMPLE STREET
# 106     PROVIDENCE TARZANA MEDICAL CENTER                  18321 CLARK STREET
# 157      ALVARADO HOSPITAL MEDICAL CENTER                  6655 ALVARADO ROAD
# 208                 SHERMAN OAKS HOSPITAL                  4929 VAN NUYS BLVD
# ...                                   ...                                 ...
# 163060      BAKERSFIELD MEMORIAL HOSPITAL                420 34TH ST BOX 1888
# 163061                 GROSSMONT HOSPITAL  5555 GROSSMONT CENTER DRIVE BOX 58
# 163062             MERCY GENERAL HOSPITAL                           4001 J ST
# 163063                 ST HELENA HOSPITAL                    10 WOODLAND ROAD
# 163064           PENINSULA MEDICAL CENTER                1501 TROUSDALE DRIVE
#
#        Provider City Provider State  Provider Zip Code  \
# 4             EUREKA             CA              95501
# 55       LOS ANGELES             CA              90026
# 106          TARZANA             CA              91356
# 157        SAN DIEGO             CA              92120
# 208     SHERMAN OAKS             CA              91403
# ...              ...            ...                ...
# 163060   BAKERSFIELD             CA              93301
# 163061       LA MESA             CA              91942
# 163062    SACRAMENTO             CA              95819
# 163063  SAINT HELENA             CA              94574
# 163064    BURLINGAME             CA              94010
#
#        Hospital Referral Region Description Total Discharges  \
# 4                              CA - Redding               48
# 55                         CA - Los Angeles               18
# 106                        CA - Los Angeles               21
# 157                          CA - San Diego               11
# 208                        CA - Los Angeles               12
# ...                                     ...              ...
# 163060                     CA - Bakersfield               21
# 163061                       CA - San Diego               26
# 163062                      CA - Sacramento               27
# 163063                            CA - Napa               17
# 163064                CA - San Mateo County               16
#
#        Average Covered Charges Average Total Payments  \
# 4                    44,664.45               8,227.14
# 55                   21,002.55               7,258.33
# 106                  38,851.04               4,739.71
# 157                  17,830.27               4,820.81
# 208                  14,632.33               4,951.50
# ...                        ...                    ...
# 163060               53,334.80               8,012.23
# 163061               40,062.46               7,449.80
# 163062               66,207.66              10,863.22
# 163063              105,929.47               9,438.00
# 163064               51,950.87               7,863.00
#
#        Average Medicare Payments  Summary Level State  State FIPS  \
# 4                       6,936.52             40    CA           6
# 55                      6,259.22             40    CA           6
# 106                     3,988.09             40    CA           6
# 157                     4,000.45             40    CA           6
# 208                     4,299.16             40    CA           6
# ...                          ...            ...   ...         ...
# 163060                  6,213.19             40    CA           6
# 163061                  6,358.07             40    CA           6
# 163062                  6,924.70             40    CA           6
# 163063                  8,376.35             40    CA           6
# 163064                  6,872.50             40    CA           6
#
#        Insured Males 18-25 Noninsured Males 18-25  \
# 4                1,458,114                515,578
# 55               1,458,114                515,578
# 106              1,458,114                515,578
# 157              1,458,114                515,578
# 208              1,458,114                515,578
# ...                    ...                    ...
# 163060           1,458,114                515,578
# 163061           1,458,114                515,578
# 163062           1,458,114                515,578
# 163063           1,458,114                515,578
# 163064           1,458,114                515,578
#
#        Females 18-25 with Insurance Females 18-25 without insurance
# 4                         1,511,793                         403,457
# 55                        1,511,793                         403,457
# 106                       1,511,793                         403,457
# 157                       1,511,793                         403,457
# 208                       1,511,793                         403,457
# ...                             ...                             ...
# 163060                    1,511,793                         403,457
# 163061                    1,511,793                         403,457
# 163062                    1,511,793                         403,457
# 163063                    1,511,793                         403,457
# 163064                    1,511,793                         403,457
#
# [13064 rows x 19 columns]

# %%
#groupby provider name 
len(healthcare_census1['Provider Zip Code'].unique().tolist())
# Out:
# 265

# %%
#datatype 
healthcare_census1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13064 entries, 4 to 163064
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DRG Definition                        13064 non-null  object
#  1   Provider Id                           13064 non-null  int64
#  2   Provider Name                         13064 non-null  object
#  3   Provider Street Address               13064 non-null  object
#  4   Provider City                         13064 non-null  object
#  5   Provider State                        13064 non-null  object
#  6   Provider Zip Code                     13064 non-null  int64
#  7   Hospital Referral Region Description  13064 non-null  object
#  8   Total Discharges                      13064 non-null  object
#  9   Average Covered Charges               13064 non-null  object
#  10  Average Total Payments                13064 non-null  object
#  11  Average Medicare Payments             13064 non-null  object
#  12  Summary Level                         13064 non-null  int64
#  13  State                                 13064 non-null  object
#  14  State FIPS                            13064 non-null  int64
#  15  Insured Males 18-25                   13064 non-null  object
#  16  Noninsured Males 18-25                13064 non-null  object
#  17  Females 18-25 with Insurance          13064 non-null  object
#  18  Females 18-25 without insurance       13064 non-null  object
# dtypes: int64(4), object(15)
# memory usage: 2.0+ MB

# %%
#describe data
healthcare_census1.describe()
# Out:
#         Provider Id  Provider Zip Code  Summary Level  State FIPS
# count  13064.000000       13064.000000        13064.0     13064.0
# mean   50317.619642       92994.223898           40.0         6.0
# std      220.954055        1795.967631            0.0         0.0
# min    50002.000000       90004.000000           40.0         6.0
# 25%    50121.000000       91710.000000           40.0         6.0
# 50%    50283.000000       92835.000000           40.0         6.0
# 75%    50488.000000       94558.000000           40.0         6.0
# max    50770.000000       96158.000000           40.0         6.0
